# %% [markdown]
# ## 1. Vehicle Routing Problem

# %%
import numpy as np
from Numberjack import *
import matplotlib.pyplot as plt
import networkx as ntx
import random

# %% [markdown]
# ### Criação do Grafo
# a) Criação de uma rede de estradas (ou seja um grafo orientado e pesado) com caminhos aleatórios e atribuição de valores às variaveis:
#
#     i)Nodes: Podem ser considerados "cidades" pois se pode (ou não) encontrar os clientes
#     ii)Carros: Número de carros que a empresa tem disponiveis
#     iii)LCarga: Limite de carga que os carros podem levar
#     iv)NumClientes: Número máximo de Clientes
#
# As arestas do grafo serão bidirecionais, pois na geração de um grafo aleatório é muito provavel haver nodos que não sejam possiveis aceder.
#
# É feita a atribuição de um "tempo" aleatório a cada aresta com um valor entre (1,10).
#
# Qualquer uma destas variáveis pode ser alterada sem correr o risco de estragar o programa desde que esta alteração seja feita com bom senso (por exemplo nao ter mais nodos que clientes ou ter qualquer um deles negativo).
#
# Também é possivel alterar a frequência de ligações e para este teste consideramos (4,0.5) a melhor combinação.

# %%
#Atribuições
Nodes = 5
Carros = 1
LCarga = 14
NumClientes = 2

g = ntx.DiGraph()
g = ntx.connected_watts_strogatz_graph(Nodes,4,0.5)

for i, j in g.edges():
    r = np.random.randint(1,10)
    g.add_edge(i,j,weight = r)
    g.add_edge(j,i,weight = r)

print("Mapa das cidades")
ntx.draw_shell(g,arrows=False,node_size=900,node_color='y',with_labels=True)
plt.show()
# Out:
# Mapa das cidades

# %% [markdown]
# Assumimos o Nodo 0 como sendo a "central" da empresa de onde partem e retornam todos os veículos.
#
# Criação de um grafo completo apartir do grafo anterior em que cada aresta é o caminho mais curto entre cada nodo.
#
# Gera-se também um array "Clientes" que contém os clientes a ser atendidos.
#
# E finalmente retira-se do grafo anterior os nodos que não são clientes ou a central da empresa e as respetivas arestas.

# %%
G = ntx.DiGraph()

G.add_nodes_from(g)
EdgesP = []

#inicializar a matriz
for i in range(Nodes):
    EdgesP.append([])
    for j in range(Nodes):
        EdgesP[i].append(-1)
        
#colocar os pesos ja calculados
for i, j, p in g.edges(data = True):
    w = p['weight']
    EdgesP[j][i] = EdgesP[i][j] = w
    G.add_edge(i, j, weight = w)
    G.add_edge(j, i, weight = w)

#calcular os caminhos mais curtos
dic = ntx.shortest_path(G, weight = 'weight')

#colocar os menores pesos
for i in range(Nodes):
    for j in range(Nodes):     
        w = 0
        for k in range(len(dic[i][j])-1):
            i1 = dic[i][j][k]
            i2 = dic[i][j][k+1]
            w += EdgesP[i1][i2]
        EdgesP[i][j] = w
        G.add_edge(i,j,weight = w)
        
#criar clientes
Clientes = np.unique(np.random.choice(range(1,Nodes), NumClientes)).tolist()
NumClientes = len(Clientes)
CargasC = np.random.randint(1,high = 5, size = NumClientes).tolist()
CargasC = dict(zip(Clientes,CargasC))
CargasC[0] = 0

#Grafo completo
print("Grafo completo")
ntx.draw_shell(G,arrows=False,node_size=900,node_color='y',with_labels=True)
plt.show()

G_clientes = G.copy()

for i in range(Nodes):
    if(i not in Clientes and i != 0 ):
        G_clientes.remove_node(i)

#Grafo final
print("Grafo final")
ntx.draw_shell(G_clientes,arrows=False,node_size=900,node_color='y',with_labels=True)
plt.show()
# Out:
# Grafo completo
# Grafo final

# %% [markdown]
# ### Restrições
#
# Para a resolução deste problema criamos uma matriz binária de carros por arestas em que:
#
#     0)Significa que o carro não utiliza aquela aresta (rua)
#     1)Significa que o carro utiliza aquela aresta (rua)
#
# ###### Obrigar a ir apenas aos clientes:
#
# $\forall_{c\leq Carros}\forall_{i\leq Nodes}\big(i \in Clientes \land i \neq 0 \Rightarrow \sum_{j\leq Nodes} Mat[c][i*Nodes+j]+Mat[c][j*Nodes+i]= 0 \big)$
#
# ###### Obrigar a que as arestas do tipo (i,i) tenham peso 0 :
#
# $\forall_{c\leq Carros}\forall_{n\leq Nodes}\big(Mat[c][n*Nodes+n]= 0 \big)$
#
# ###### Obrigar os clientes a serem atendidos uma unica vez:
#
# $\forall_{c\leq Clientes}\big(\sum_{i\leq Carros, j\leq Nodes}Mat[i][c*Nodes+j]= 1 \big)$
# $\forall_{c\leq Clientes}\big(\sum_{i\leq Carros, j\leq Nodes}Mat[i][j*Nodes+c]= 1 \big)$
#
# ###### Obrigar a começar e acabar no 0:
#
# $\forall_{c\leq Carros}\big(\sum_{i\leq Nodes}Mat[c][0*Nodes+i]= \big(\big(\sum_{e\leq Nodes²} Mat[c][e]\big)>0\big) \big)$
# $\forall_{c\leq Carros}\big(\sum_{i\leq Nodes}Mat[c][i*Nodes+0]= \big(\big(\sum_{e\leq Nodes²} Mat[c][e]\big)>0\big) \big)$
#
# ###### Minimizar os carros:
#
# $minimize\big(\sum_{c\leq Carros}\big(\sum_{e\leq Nodes²}Mat[c][e]\big)>0\big)$
#
# ###### Minimizar o custo (tempo):
#
# $\forall_{c\leq Carros}minimize\big(\sum_{i\leq Nodes,j\leq Nodes}EdgesP[i][j]*Mat[c][i*Nodes + j]\big)$
#
# ###### Verificar que o caminho faz sentido:
#
# $\forall_{c\leq Carros}\forall_{i\leq Clientes}\big(\sum_{j\leq Nodes}Mat[c][i*Nodes+j]-Mat[c][j*Nodes+i]=0\big)$
#
# ###### Verificar que nao excede a carga maxima:
#
# $\forall_{c\leq Carros}\big(\sum_{e\leq Nodes²}Mat[c][e]*CargasC[e\mod Nodes] \leq LCarga \big)$

# %%
Mat = Matrix(Carros,Nodes,NumClientes)
model = Model()

X = [[[ ((Mat[c][i]>0)*(Mat[c][j]>0)*(Mat[c][i]+1 == Mat[c][j]))+(i==0 & Mat[c][j]==1)>0 for j in range(Nodes)] \
                                                                                         for i in range(Nodes)] \
                                                                                         for c in range(Carros)]

#obrigar a ir apenas aos clientes

for c in range(Carros):
    for i in range(Nodes):
        if(i not in Clientes and i != 0 ):
            model.add( Mat[c][i] == 0 )

#Obrigar a que as arestas do tipo (i,i) sejam 0
'''
for c in range(Carros):
    for n in range(Nodes):
        model.add(Mat[c][n*Nodes+n]==0)
'''        
        
#Obrigar os clientes a serem atendidos uma unica vez

for cl in Clientes:
    model.add( Sum([ X[ca][cl][i] for ca in range(Carros) for i in range(Nodes)]) == 1)
    model.add( Sum([ X[ca][i][cl] for ca in range(Carros) for i in range(Nodes)]) == 1)

    
'''
for c in Clientes:
    A = [ Mat[i][c*Nodes+j] for i in range(Carros) for j in range(Nodes) ]
    B = [ Mat[i][j*Nodes+c] for i in range(Carros) for j in range(Nodes) ]
    model.add( Sum(A) == 1 )
    model.add( Sum(B) == 1 )
'''
#Obrigar a começar e acabar no 0

for c in range(Carros):
    model.add( Sum([ X[c][i][0] for i in range(Nodes)]) == (Mat[c][0]>1) )
'''   
    # p = 1 se o carro esta, p = 0 se o carro nao esta
    p = (Sum([ Mat[c][e] for e in range(Nodes**2)]) > 0)
    model.add( Sum([ Mat[c][0*Nodes + i] for i in range(Nodes)]) == p )
    model.add( Sum([ Mat[c][i*Nodes + 0] for i in range(Nodes)]) == p )
'''
    
#Minimizar os carros
model += Minimise(Sum([ (Mat[c][0]>1) for c in range(Carros)]))
'''model += Minimise(Sum([ (Sum(Mat[c]) > 1) for c in range(Carros)]))'''

#Minimizar o custo

for c in range(Carros):
    model += Minimise(Sum([ EdgesP[i][j]*(X[c][i][j]) for i in range(Nodes)\
                                                      for j in range(Nodes)]))
#Verificar que o caminho faz sentido

'''
for c in range(Carros):
    model.add( AllDiff([  for i in range(Nodes) for j in range(Nodes)]) )

for c in range(Carros):
    for i in range(Nodes):  
        model.add( Sum([ Mat[c][i*Nodes+j]-Mat[c][j*Nodes+i] for j in range(Nodes)]) == 0 )
        
    #obrigar a que nao haja ciclos distintos
    #for i in range(1, Nodes):
     #   for j in range(1, Nodes):
      #      model.add( Mat[c][i*Nodes+j]+Mat[c][j*Nodes+i] <= 1 )
    
    u=[0]*Nodes
    u[0]=1
    for i in range(NumClientes):
        for j in range(NumClientes):
            u[j]+= (u[i] > 0)*Mat[c][i*Nodes+j]*(u[j] == 0)
    #model.add(Sum([Mat[c][e] for e in range(Nodes**2)]) == Sum(u))
    for i in range(1,Nodes):
        for j in range(1,Nodes):
            #model.add(u[i]-u[j]+Nodes*Mat[c][i*Nodes+j] <= Nodes-1)
            model.add( (u[i]>u[j]) >= Mat[c][i*Nodes+j] )
'''
    
#Verificar que nao excede a carga maxima

for c in range(Carros):
    model.add( Sum( [ CargasC.get(j, 0)*X[c][i][j] for i in range(Nodes) for j in range(Nodes) ] ) <= LCarga )

print()
#print(model)
model.load('SCIP').solve()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-21-a8fe644c126c> in <module>()
#      85 print()
#      86 #print(model)
# ---> 87 model.load('SCIP').solve()
#
# /usr/local/lib/python3.5/dist-packages/Numberjack/__init__.py in load(self, solvername, X, encoding)
#     909             solverstring = "%s.%s" % (solverspkg, solvername)
#     910             lib = __import__(solverstring, fromlist=[solverspkg])
# --> 911             solver = lib.Solver(self, X, encoding=encoding)
#     912         except ImportError:
#     913             raise ImportError(
#
# /usr/local/lib/python3.5/dist-packages/Numberjack/solvers/SCIP.py in __init__(self, model, X, FD, clause_limit, encoding)
#     167 class Solver(Numberjack.NBJ_STD_Solver):
#     168     def __init__(self, model=None, X=None, FD=False, clause_limit=-1, encoding=None):
# --> 169         Numberjack.NBJ_STD_Solver.__init__(self, "SCIP", "MipWrapper", model, X, FD, clause_limit, encoding)
#     170
#     171
#
# /usr/local/lib/python3.5/dist-packages/Numberjack/__init__.py in __init__(self, Library, Wrapper, model, X, FD, clause_limit, encoding)
#    3173             loadstart = datetime.datetime.now()
#    3174             for expr in self.model.get_exprs():
# -> 3175                 self.solver.add(self.load_expr(expr))
#    3176             self.load_time = total_seconds(datetime.datetime.now() - loadstart)
#    3177
#
# /usr/local/lib/python3.5/dist-packages/Numberjack/__init__.py in load_expr(self, expr)
#    3284                 arguments = None
#    3285                 if len(expr.get_children()) <= 2:
# -> 3286                     arguments = [self.load_expr(child) for child in expr.get_children()]
#    3287                 else:
#    3288                     var_array = self.ExpArray()
#
# /usr/local/lib/python3.5/dist-packages/Numberjack/__init__.py in <listcomp>(.0)
#    3284                 arguments = None
#    3285                 if len(expr.get_children()) <= 2:
# -> 3286                     arguments = [self.load_expr(child) for child in expr.get_children()]
#    3287                 else:
#    3288                     var_array = self.ExpArray()
#
# /usr/local/lib/python3.5/dist-packages/Numberjack/__init__.py in load_expr(self, expr)
#    3288                     var_array = self.ExpArray()
#    3289                     for child in expr.get_children():
# -> 3290                         myarg = self.load_expr(child)
#    3291                         var_array.add(myarg)
#    3292                         keep_alive.append(myarg)
#
# /usr/local/lib/python3.5/dist-packages/Numberjack/__init__.py in load_expr(self, expr)
#    3284                 arguments = None
#    3285                 if len(expr.get_children()) <= 2:
# -> 3286                     arguments = [self.load_expr(child) for child in expr.get_children()]
#    3287                 else:
#    3288                     var_array = self.ExpArray()
#
# /usr/local/lib/python3.5/dist-packages/Numberjack/__init__.py in <listcomp>(.0)
#    3284                 arguments = None
#    3285                 if len(expr.get_children()) <= 2:
# -> 3286                     arguments = [self.load_expr(child) for child in expr.get_children()]
#    3287                 else:
#    3288                     var_array = self.ExpArray()
#
# /usr/local/lib/python3.5/dist-packages/Numberjack/__init__.py in load_expr(self, expr)
#    3284                 arguments = None
#    3285                 if len(expr.get_children()) <= 2:
# -> 3286                     arguments = [self.load_expr(child) for child in expr.get_children()]
#    3287                 else:
#    3288                     var_array = self.ExpArray()
#
# /usr/local/lib/python3.5/dist-packages/Numberjack/__init__.py in <listcomp>(.0)
#    3284                 arguments = None
#    3285                 if len(expr.get_children()) <= 2:
# -> 3286                     arguments = [self.load_expr(child) for child in expr.get_children()]
#    3287                 else:
#    3288                     var_array = self.ExpArray()
#
# /usr/local/lib/python3.5/dist-packages/Numberjack/__init__.py in load_expr(self, expr)
#    3284                 arguments = None
#    3285                 if len(expr.get_children()) <= 2:
# -> 3286                     arguments = [self.load_expr(child) for child in expr.get_children()]
#    3287                 else:
#    3288                     var_array = self.ExpArray()
#
# /usr/local/lib/python3.5/dist-packages/Numberjack/__init__.py in <listcomp>(.0)
#    3284                 arguments = None
#    3285                 if len(expr.get_children()) <= 2:
# -> 3286                     arguments = [self.load_expr(child) for child in expr.get_children()]
#    3287                 else:
#    3288                     var_array = self.ExpArray()
#
# /usr/local/lib/python3.5/dist-packages/Numberjack/__init__.py in load_expr(self, expr)
#    3313                             arguments.append(param)
#    3314                 try:
# -> 3315                     var = factory(*arguments)
#    3316                 except NotImplementedError as e:
#    3317                     print("Error the solver does not support this expression:", str(expr), file=sys.stderr)
#
# /usr/local/lib/python3.5/dist-packages/Numberjack/solvers/MipWrapper.py in __init__(self, var1, var2)
#     655
#     656     def __init__(self, var1, var2):
# --> 657         this = _MipWrapper.new_MipWrapper_and(var1, var2)
#     658         try:
#     659             self.this.append(this)
#
# TypeError: in method 'new_MipWrapper_and', argument 2 of type 'MipWrapper_Expression *'

# %% [markdown]
# ### Resultado Final

# %%
print("Lista de Clientes:")
print(Clientes)

for c in range(Carros):
    print("\nCarro",c+1)
    
    Gaux = ntx.DiGraph()

    Gaux.add_nodes_from(g)

    for i in range(Nodes):
        for j in range(Nodes):
            if(Mat[c][i*Nodes+j].get_value()==1):
                Gaux.add_edge(i,j)

    ntx.draw_shell(Gaux,arrows=True,node_size=500,node_color='y',with_labels=True)
    plt.show()
    
    atual = 0
    caminho = []
    c2 = []
    
    for i in range(Nodes):
        if(Mat[c][atual*Nodes + i].get_value() == 1):
            caminho = caminho + dic[atual][i]
            caminho.pop()
            atual = i
            c2.append(atual)
            break
    while(atual != 0):
        for i in range(Nodes):
            if(Mat[c][atual*Nodes + i].get_value() == 1):
                caminho = caminho + dic[atual][i]
                caminho.pop()
                atual = i
                c2.append(atual)
                break
    caminho.append(0)
    print("Percurso:",caminho)
    carga = 0
    for c in c2:
        carga = carga + CargasC.get(c, 0)
    print("Carga:",carga)

# %% [markdown]
# ## 2. Sudoku

# %% [markdown]
# ### Criação do sudoku

# %%
N = 3
NS = N*N
Gre = Matrix(NS,NS,1,NS)
model = Model()

# %% [markdown]
# ### Restrições
# Preencher a Grelha
#
# ###### Todos os pequenos quadrados têm diferentes números
#
# $\forall_{i< N²}\forall_{j< N²}\forall_{i<i2\leq N²}
# \forall_{j<j2\leq N²}\big(M[i,j] =M[i2,j2] \Rightarrow \big(i/N \neq i2/N\big) \vee \big(j/N \neq j2/N\big)  \big)$
#
# ###### Todas as linhas têm diferentes números
#
# $\forall_{i\leq N²}\forall_{j< N²}\forall_{j<j2\leq N²}\big(M[i,j] \neq M[i,j2] \big)$
#
# ###### Todas as colunas têm diferentes números
#
# $\forall_{i< N²}\forall_{i<i2\leq N²}\forall_{j\leq N²}\big(M[i,j] \neq M[i2,j] \big)$

# %%
for i in range(N):
    for j in range(N):
        model.add(AllDiff(Gre[i*N:(i+1)*N,j*N:(j+1)*N].flat))
        model.add(AllDiff(Gre[i*N+j]))
        model.add(AllDiff(Gre.col[i*N+j]))

# %% [markdown]
# ### Resolução

# %%
model.load('SCIP').solve()

print(Gre)
